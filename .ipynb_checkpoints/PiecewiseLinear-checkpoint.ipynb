# %% [markdown]
# # Import Packages

# %%
using Gurobi
using PiecewiseLinear

# %% [markdown]
# ## Use 5 linear functions to approximate:
# $$ f:[0,6] \rightarrow \mathbb{R} $$
# $$f(x) = x^2 - 3x +2 $$

# %% [markdown]
# ## 1) Norm $L^1$

# %%
prb = create((x->x^2-3x+2), collect(0.0:0.1:6.0), 5, Gurobi.Optimizer);
fit!(prb);
plot(prb)
# Out:
# Academic license - for non-commercial use only - expires 2023-08-07

# %% [markdown]
# ## 2) Norm $L^2$

# %%
prb = create((x->x^2-3x+2), collect(0.0:0.1:6.0), 5, Gurobi.Optimizer, norm=PiecewiseLinear.L2);
fit!(prb);
plot(prb)
# Out:
# Academic license - for non-commercial use only - expires 2023-08-07

# %% [markdown]
# ## 3) Norm $L^\infty$

# %%
prb = create((x->x^2-3x+2), collect(0.0:0.1:6.0), 5, Gurobi.Optimizer, norm=PiecewiseLinear.Linf);
fit!(prb);
plot(prb)
# Out:
# Academic license - for non-commercial use only - expires 2023-08-07

# %% [markdown]
# ## Impose convex or concave:

# %%
prb = create((x->sin(x/10)), collect(0.0:0.5:6.0), 5, Gurobi.Optimizer, force_prop=PiecewiseLinear.convex);
fit!(prb);
plot(prb)
# Out:
# Academic license - for non-commercial use only - expires 2023-08-07
# UndefVarError: convex not defined
#
# Stacktrace:
#  [1] _add_constraints!(prb::PiecewiseLinear.Problem)
#    @ PiecewiseLinear D:\GitHub\PiecewiseLinear.jl\src\model.jl:81
#  [2] _create_model!(prb::PiecewiseLinear.Problem)
#    @ PiecewiseLinear D:\GitHub\PiecewiseLinear.jl\src\model.jl:28
#  [3] prepare!(prb::PiecewiseLinear.Problem)
#    @ PiecewiseLinear D:\GitHub\PiecewiseLinear.jl\src\user_interface.jl:27
#  [4] create(f::var"#1#2", grid::Vector{Float64}, pieces::Int64, solver::DataType; norm::PiecewiseLinear.Norm, force_prop::PiecewiseLinear.ForceProp, weights::PiecewiseLinear.var"#37#39", force_y::Dict{Int64, Float64})
#    @ PiecewiseLinear D:\GitHub\PiecewiseLinear.jl\src\user_interface.jl:20
#  [5] top-level scope
#    @ In[2]:1
#  [6] eval
#    @ .\boot.jl:360 [inlined]
#  [7] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1116

# %%
PiecewiseLinear.convex
# Out:
# convex::ForceProp = 2
